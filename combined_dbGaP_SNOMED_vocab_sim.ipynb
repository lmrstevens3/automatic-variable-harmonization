# %%
from automatic_variable_mapping import tfidf

# %%
from automatic_variable_mapping import corpus, vocab_similarity
import pandas as pd
import time
import numpy as np
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/harrison/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /home/harrison/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# doc_col = list("var_desc_1”, “units_1, “var_coding_counts_distribution_1)
data_file = "SNOMED-concepts/output/combined_FHS_SNOMED.csv"
filt_file = "tests/manualConceptVariableMappings_dbGaP_Aim1_contVarNA_NLP.csv"
score_file = 'tests/test_var_similarity_scores_rank_data.csv'

# %%
data = pd.read_csv(data_file,
                      sep=",",
                      quotechar='"',
                      na_values="",
                      low_memory=False)
data
# Out:
#         Unnamed: 0 dbGaP_study_id   dbGaP_dataset_id  \
# 0                0  phs000007.v26       pht000009.v2
# 1                1  phs000007.v26       pht000009.v2
# 2                2  phs000007.v26       pht000009.v2
# 3                3  phs000007.v26       pht000009.v2
# 4                4  phs000007.v26       pht000009.v2
# 5                5  phs000007.v26       pht000009.v2
# 6                6  phs000007.v26       pht000009.v2
# 7                7  phs000007.v26       pht000009.v2
# 8                8  phs000007.v26       pht000009.v2
# 9                9  phs000007.v26       pht000009.v2
# 10              10  phs000007.v26       pht000009.v2
# 11              11  phs000007.v26       pht000009.v2
# 12              12  phs000007.v26       pht000009.v2
# 13              13  phs000007.v26       pht000009.v2
# 14              14  phs000007.v26       pht000009.v2
# 15              15  phs000007.v26       pht000009.v2
# 16              16  phs000007.v26       pht000009.v2
# 17              17  phs000007.v26       pht000009.v2
# 18              18  phs000007.v26       pht000009.v2
# 19              19  phs000007.v26       pht000009.v2
# 20              20  phs000007.v26       pht000009.v2
# 21              21  phs000007.v26       pht000009.v2
# 22              22  phs000007.v26       pht000009.v2
# 23              23  phs000007.v26       pht000009.v2
# 24              24  phs000007.v26       pht000009.v2
# 25              25  phs000007.v26       pht000009.v2
# 26              26  phs000007.v26       pht000009.v2
# 27              27  phs000007.v26       pht000009.v2
# 28              28  phs000007.v26       pht000009.v2
# 29              29  phs000007.v26       pht000009.v2
# ...            ...            ...                ...
# 133527       27916         SNOMED   Clinical Finding
# 133528       27917         SNOMED          Procedure
# 133529       27918         SNOMED          Substance
# 133530       27919         SNOMED   Clinical Finding
# 133531       27920         SNOMED          Procedure
# 133532       27921         SNOMED          Procedure
# 133533       27922         SNOMED   Clinical Finding
# 133534       27923         SNOMED   Clinical Finding
# 133535       27924         SNOMED   Clinical Finding
# 133536       27925         SNOMED          Procedure
# 133537       27926         SNOMED   Clinical Finding
# 133538       27927         SNOMED  Observable Entity
# 133539       27928         SNOMED          Substance
# 133540       27929         SNOMED   Clinical Finding
# 133541       27930         SNOMED          Procedure
# 133542       27931         SNOMED   Clinical Finding
# 133543       27932         SNOMED   Clinical Finding
# 133544       27933         SNOMED          Substance
# 133545       27934         SNOMED          Substance
# 133546       27935         SNOMED          Procedure
# 133547       27936         SNOMED          Procedure
# 133548       27937         SNOMED          Substance
# 133549       27938         SNOMED          Procedure
# 133550       27939         SNOMED          Procedure
# 133551       27940         SNOMED          Substance
# 133552       27941         SNOMED          Procedure
# 133553       27942         SNOMED          Procedure
# 133554       27943         SNOMED   Clinical Finding
# 133555       27944         SNOMED          Procedure
# 133556       27945         SNOMED   Clinical Finding
#
#                              dataset_description variable_id  \
# 0       Clinic Exam, Original Cohort Exams 1 - 7         MF4
# 1       Clinic Exam, Original Cohort Exams 1 - 7         MF5
# 2       Clinic Exam, Original Cohort Exams 1 - 7         MF6
# 3       Clinic Exam, Original Cohort Exams 1 - 7         MF8
# 4       Clinic Exam, Original Cohort Exams 1 - 7         MF9
# 5       Clinic Exam, Original Cohort Exams 1 - 7        MF10
# 6       Clinic Exam, Original Cohort Exams 1 - 7        MF11
# 7       Clinic Exam, Original Cohort Exams 1 - 7        MF12
# 8       Clinic Exam, Original Cohort Exams 1 - 7        MF13
# 9       Clinic Exam, Original Cohort Exams 1 - 7        MF14
# 10      Clinic Exam, Original Cohort Exams 1 - 7        MF15
# 11      Clinic Exam, Original Cohort Exams 1 - 7        MF16
# 12      Clinic Exam, Original Cohort Exams 1 - 7        MF17
# 13      Clinic Exam, Original Cohort Exams 1 - 7        MF18
# 14      Clinic Exam, Original Cohort Exams 1 - 7        MF19
# 15      Clinic Exam, Original Cohort Exams 1 - 7        MF20
# 16      Clinic Exam, Original Cohort Exams 1 - 7        MF21
# 17      Clinic Exam, Original Cohort Exams 1 - 7        MF22
# 18      Clinic Exam, Original Cohort Exams 1 - 7        MF23
# 19      Clinic Exam, Original Cohort Exams 1 - 7        MF24
# 20      Clinic Exam, Original Cohort Exams 1 - 7        MF25
# 21      Clinic Exam, Original Cohort Exams 1 - 7        MF26
# 22      Clinic Exam, Original Cohort Exams 1 - 7        MF27
# 23      Clinic Exam, Original Cohort Exams 1 - 7        MF28
# 24      Clinic Exam, Original Cohort Exams 1 - 7        MF29
# 25      Clinic Exam, Original Cohort Exams 1 - 7        MF30
# 26      Clinic Exam, Original Cohort Exams 1 - 7        MF31
# 27      Clinic Exam, Original Cohort Exams 1 - 7        MF32
# 28      Clinic Exam, Original Cohort Exams 1 - 7        MF33
# 29      Clinic Exam, Original Cohort Exams 1 - 7        MF34
# ...                                          ...         ...
# 133527                                       NaN         NaN
# 133528                                       NaN         NaN
# 133529                                       NaN         NaN
# 133530                                       NaN         NaN
# 133531                                       NaN         NaN
# 133532                                       NaN         NaN
# 133533                                       NaN         NaN
# 133534                                       NaN         NaN
# 133535                                       NaN         NaN
# 133536                                       NaN         NaN
# 133537                                       NaN         NaN
# 133538                                       NaN         NaN
# 133539                                       NaN         NaN
# 133540                                       NaN         NaN
# 133541                                       NaN         NaN
# 133542                                       NaN         NaN
# 133543                                       NaN         NaN
# 133544                                       NaN         NaN
# 133545                                       NaN         NaN
# 133546                                       NaN         NaN
# 133547                                       NaN         NaN
# 133548                                       NaN         NaN
# 133549                                       NaN         NaN
# 133550                                       NaN         NaN
# 133551                                       NaN         NaN
# 133552                                       NaN         NaN
# 133553                                       NaN         NaN
# 133554                                       NaN         NaN
# 133555                                       NaN         NaN
# 133556                                       NaN         NaN
#
#                                      variable_description  \
# 0                                 RELATIVE WEIGHT, EXAM 1
# 1                                               EDUCATION
# 2                                        COUNTRY OF BIRTH
# 3                     HISTORY OF ACUTE INFECTIONS, EXAM 1
# 4                      HISTORY OF RHEUMATIC FEVER, EXAM 1
# 5                    HISTORY OF ALLERGY OR ASTHMA, EXAM 1
# 6       HISTORY OF CHRONIC ARTHRITIS AND RHEUMATISM, E...
# 7                      HISTORY OF THYROID DISEASE, EXAM 1
# 8                         HISTORY OF HYPERTENSION, EXAM 1
# 9                       HISTORY OF ENLARGED HEART, EXAM 1
# 10                       HISTORY OF NERVOUS HEART, EXAM 1
# 11                        HISTORY OF PERICARDITIS, EXAM 1
# 12               HISTORY OF SUBACUTE ENDOCARDITIS, EXAM 1
# 13        HISTORY OF OTHER CARDIOVASCULAR DISEASE, EXAM 1
# 14      HISTORY OF NON-CARDIOVASCULAR DISEASE, EXAM 1 ...
# 15                          NUMBER OF PREGNANCIES, EXAM 1
# 16           TOXEMIA WITH ONE OR MORE PREGNANCIES, EXAM 1
# 17      HISTORY OF DRUGS TAKEN: DIGITALIS OR NITRITES,...
# 18      EXAMINATION: INCREASE IN CHEST CIRCUMFERENCE, ...
# 19      EYE EXAMINATION: EXOPHTHALMOS, ARCUS SENILIS, ...
# 20                        EYE EXAMINATION: RETINA, EXAM 1
# 21                   CHEST EXAMINATION: DEFORMITY, EXAM 1
# 22      CHEST EXAMINATION: APEX IMPULSE OUTSIDE MIDCLA...
# 23                       CHEST EXAMINATION: RALES, EXAM 1
# 24      CHEST EXAMINATION: IRREGULAR CARDIAC RHYTHM, E...
# 25                 X-RAY: GENERALIZED HYPERTROPHY, EXAM 1
# 26            X-RAY: LEFT VENTRICULAR HYPERTROPHY, EXAM 1
# 27             X-RAY: OTHER HYPERTROPHY (AH, RVH), EXAM 1
# 28      X-RAY: ABNORMAL CONTOUR OTHER THAN HYPERTROPHY...
# 29                  X-RAY: ABNORMAL GREAT VESSELS, EXAM 1
# ...                                                   ...
# 133527                                   Born in Thailand
# 133528               Replacement of suppository in vagina
# 133529                                        Iridium-190
# 133530                    Blister of flank with infection
# 133531           Special schooling for handicapped person
# 133532  Radical maxillary sinusotomy with removal of a...
# 133533             Osteonecrosis of radius caused by drug
# 133534  Open wound of alveolar process without complic...
# 133535           Infant formula for metabolic dysfunction
# 133536                            MRI of bilateral wrists
# 133537         Curvature of spine due to another disorder
# 133538                                       Suicide risk
# 133539                                 3-methyl histidine
# 133540                      Multiple personality disorder
# 133541                  Repair of tendon by direct suture
# 133542                                Personal motivation
# 133543             Transitory neonatal hypoparathyroidism
# 133544                             Hydrophilic petrolatum
# 133545                                         Difenamide
# 133546                          Culture of dialysis fluid
# 133547                             Gadolinium measurement
# 133548                                         Xenon-127m
# 133549  Reconstruction of angular deformity of toe by ...
# 133550                                 Grafting of nipple
# 133551                        Racepinefrine hydrochloride
# 133552      Pump extraction of milk from lactating breast
# 133553                       Intracardiac phonocardiogram
# 133554         Acute adenoviral follicular conjunctivitis
# 133555       Stereotactic focused proton beam on cerebrum
# 133556                                     Injury of lung
#
#                         units  \
# 0                     PERCENT
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15      NUMBER OF PREGNANCIES
# 16                        NaN
# 17                        NaN
# 18                     INCHES
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
# ...                       ...
# 133527                    NaN
# 133528                    NaN
# 133529                    NaN
# 133530                    NaN
# 133531                    NaN
# 133532                    NaN
# 133533                    NaN
# 133534                    NaN
# 133535                    NaN
# 133536                    NaN
# 133537                    NaN
# 133538                    NaN
# 133539                    NaN
# 133540                    NaN
# 133541                    NaN
# 133542                    NaN
# 133543                    NaN
# 133544                    NaN
# 133545                    NaN
# 133546                    NaN
# 133547                    NaN
# 133548                    NaN
# 133549                    NaN
# 133550                    NaN
# 133551                    NaN
# 133552                    NaN
# 133553                    NaN
# 133554                    NaN
# 133555                    NaN
# 133556                    NaN
#
#                                    variable_coding_labels study  \
# 0                                                     NaN   FHS
# 1       FIFTH, SIXTH OR SEVENTH GRADE; NONE; POST GRAD...   FHS
# 2        BORN IN UNITED STATES; NOT BORN IN UNITED STATES   FHS
# 3       SCARLET FEVER; NEGATIVE; DIPHTHERIA AND FREQUE...   FHS
# 4                            NONE; DOUBTFUL; UNKNOWN; YES   FHS
# 5       BRONCHIAL ASTHMA, ALONE; NEGATIVE; UNKNOWN; AL...   FHS
# 6                                        NO; UNKNOWN; YES   FHS
# 7       HYPOTHYROID ONLY; NEGATIVE; DOUBTFUL; HYPERTHY...   FHS
# 8       PERMANENT; NEGATIVE; DOUBTFUL; UNKNOWN; TRANSI...   FHS
# 9                                        NO; UNKNOWN; YES   FHS
# 10                                       NO; UNKNOWN; YES   FHS
# 11                                       NO; UNKNOWN; YES   FHS
# 12                                       NO; UNKNOWN; YES   FHS
# 13                                       NO; UNKNOWN; YES   FHS
# 14      CHRONIC COLITIS; NEGATIVE; DOUBTFUL; ULCER AND...   FHS
# 15      MAN, SINGLE WOMAN, OR NO PREGNANCIES FOR NON-S...   FHS
# 16      NO; YES; MAN, SINGLE WOMAN, OR NO PREGNANCIES ...   FHS
# 17      NITRITES, ALONE; NEGATIVE; UNKNOWN; DIGITALIS,...   FHS
# 18      1.0--1.4; LESS THAN 0.5; 4.0 OR OVER; 2.5--2.9...   FHS
# 19      ARCUS SENILIS, ALONE; NONE OF THESE; ARCUS SEN...   FHS
# 20      ABNORMAL, GROUP II; NORMAL; ABNORMAL, GROUP UN...   FHS
# 21                                       NO; UNKNOWN; YES   FHS
# 22                                       NO; UNKNOWN; YES   FHS
# 23                                       NO; UNKNOWN; YES   FHS
# 24                                       NO; UNKNOWN; YES   FHS
# 25              YES, DOUBTFUL; NO; UNKNOWN; YES, DEFINITE   FHS
# 26              YES, DOUBTFUL; NO; UNKNOWN; YES, DEFINITE   FHS
# 27              YES, DOUBTFUL; NO; UNKNOWN; YES, DEFINITE   FHS
# 28              YES, DOUBTFUL; NO; UNKNOWN; YES, DEFINITE   FHS
# 29              YES, DOUBTFUL; NO; UNKNOWN; YES, DEFINITE   FHS
# ...                                                   ...   ...
# 133527                                                NaN   NaN
# 133528                                                NaN   NaN
# 133529                                                NaN   NaN
# 133530                                                NaN   NaN
# 133531                                                NaN   NaN
# 133532                                                NaN   NaN
# 133533                                                NaN   NaN
# 133534                                                NaN   NaN
# 133535                                                NaN   NaN
# 133536                                                NaN   NaN
# 133537                                                NaN   NaN
# 133538                                                NaN   NaN
# 133539                                                NaN   NaN
# 133540                                                NaN   NaN
# 133541                                                NaN   NaN
# 133542                                                NaN   NaN
# 133543                                                NaN   NaN
# 133544                                                NaN   NaN
# 133545                                                NaN   NaN
# 133546                                                NaN   NaN
# 133547                                                NaN   NaN
# 133548                                                NaN   NaN
# 133549                                                NaN   NaN
# 133550                                                NaN   NaN
# 133551                                                NaN   NaN
# 133552                                                NaN   NaN
# 133553                                                NaN   NaN
# 133554                                                NaN   NaN
# 133555                                                NaN   NaN
# 133556                                                NaN   NaN
#
#        dbGaP_dataset_label                variable_coding_counts_distribution  \
# 0                   ex0_7s  n=5036; nulls=43; mean=102.2; sd=16.8; median=...
# 1                   ex0_7s  n=4884; nulls=195; HIGH SCHOOL GRADUATE=5:coun...
# 2                   ex0_7s  n=5079; nulls=0; BORN IN UNITED STATES=0:count...
# 3                   ex0_7s  n=5029; nulls=50; NEGATIVE=0:count=3087; FREQU...
# 4                   ex0_7s  n=5065; nulls=14; NONE=0:count=4738; YES=1:cou...
# 5                   ex0_7s  n=5019; nulls=60; NEGATIVE=0:count=4467; ALLER...
# 6                   ex0_7s  n=5019; nulls=60; NO=0:count=4360; YES=1:count...
# 7                   ex0_7s  n=5054; nulls=25; NEGATIVE=0:count=4726; OTHER...
# 8                   ex0_7s  n=5074; nulls=5; NEGATIVE=0:count=4328; TYPE U...
# 9                   ex0_7s  n=4943; nulls=136; NO=0:count=4861; YES=1:coun...
# 10                  ex0_7s  n=4943; nulls=136; NO=0:count=4899; YES=1:coun...
# 11                  ex0_7s  n=4943; nulls=136; NO=0:count=4934; YES=1:coun...
# 12                  ex0_7s  n=4943; nulls=136; NO=0:count=4938; YES=1:coun...
# 13                  ex0_7s  n=4943; nulls=136; NO=0:count=4756; YES=1:coun...
# 14                  ex0_7s  n=5043; nulls=36; NEGATIVE=0:count=4258; KIDNE...
# 15                  ex0_7s  n=2122; nulls=17; mean=2.82; sd=1.353; median=...
# 16                  ex0_7s  n=5079; nulls=0; MAN, SINGLE WOMAN, OR NO PREG...
# 17                  ex0_7s  n=4935; nulls=144; NEGATIVE=0:count=4776; DIGI...
# 18                  ex0_7s  n=4976; nulls=103; 4.0 OR OVER=8:count=1123; 3...
# 19                  ex0_7s  n=4823; nulls=256; NONE OF THESE=0:count=4242;...
# 20                  ex0_7s  n=4823; nulls=256; NORMAL=0:count=3779; ABNORM...
# 21                  ex0_7s  n=4738; nulls=341; NO=0:count=4333; YES=1:coun...
# 22                  ex0_7s  n=4738; nulls=341; NO=0:count=4536; YES=1:coun...
# 23                  ex0_7s  n=4738; nulls=341; NO=0:count=4499; YES=1:coun...
# 24                  ex0_7s  n=4738; nulls=341; NO=0:count=4560; YES=1:coun...
# 25                  ex0_7s  n=5048; nulls=31; NO=0:count=4581; YES, DEFINI...
# 26                  ex0_7s  n=5048; nulls=31; NO=0:count=4271; YES, DEFINI...
# 27                  ex0_7s  n=5048; nulls=31; NO=0:count=4990; YES, DOUBTF...
# 28                  ex0_7s  n=5048; nulls=31; NO=0:count=4974; YES, DEFINI...
# 29                  ex0_7s  n=5048; nulls=31; NO=0:count=3680; YES, DEFINI...
# ...                    ...                                                ...
# 133527                 NaN                                                NaN
# 133528                 NaN                                                NaN
# 133529                 NaN                                                NaN
# 133530                 NaN                                                NaN
# 133531                 NaN                                                NaN
# 133532                 NaN                                                NaN
# 133533                 NaN                                                NaN
# 133534                 NaN                                                NaN
# 133535                 NaN                                                NaN
# 133536                 NaN                                                NaN
# 133537                 NaN                                                NaN
# 133538                 NaN                                                NaN
# 133539                 NaN                                                NaN
# 133540                 NaN                                                NaN
# 133541                 NaN                                                NaN
# 133542                 NaN                                                NaN
# 133543                 NaN                                                NaN
# 133544                 NaN                                                NaN
# 133545                 NaN                                                NaN
# 133546                 NaN                                                NaN
# 133547                 NaN                                                NaN
# 133548                 NaN                                                NaN
# 133549                 NaN                                                NaN
# 133550                 NaN                                                NaN
# 133551                 NaN                                                NaN
# 133552                 NaN                                                NaN
# 133553                 NaN                                                NaN
# 133554                 NaN                                                NaN
# 133555                 NaN                                                NaN
# 133556                 NaN                                                NaN
#
#        var_doc_id      study_dataset_dbGaP_id
# 0        FHS1var1  phs000007.v26.pht000009.v2
# 1        FHS1var2  phs000007.v26.pht000009.v2
# 2        FHS1var3  phs000007.v26.pht000009.v2
# 3        FHS1var4  phs000007.v26.pht000009.v2
# 4        FHS1var5  phs000007.v26.pht000009.v2
# 5        FHS1var6  phs000007.v26.pht000009.v2
# 6        FHS1var7  phs000007.v26.pht000009.v2
# 7        FHS1var8  phs000007.v26.pht000009.v2
# 8        FHS1var9  phs000007.v26.pht000009.v2
# 9       FHS1var10  phs000007.v26.pht000009.v2
# 10      FHS1var11  phs000007.v26.pht000009.v2
# 11      FHS1var12  phs000007.v26.pht000009.v2
# 12      FHS1var13  phs000007.v26.pht000009.v2
# 13      FHS1var14  phs000007.v26.pht000009.v2
# 14      FHS1var15  phs000007.v26.pht000009.v2
# 15      FHS1var16  phs000007.v26.pht000009.v2
# 16      FHS1var17  phs000007.v26.pht000009.v2
# 17      FHS1var18  phs000007.v26.pht000009.v2
# 18      FHS1var19  phs000007.v26.pht000009.v2
# 19      FHS1var20  phs000007.v26.pht000009.v2
# 20      FHS1var21  phs000007.v26.pht000009.v2
# 21      FHS1var22  phs000007.v26.pht000009.v2
# 22      FHS1var23  phs000007.v26.pht000009.v2
# 23      FHS1var24  phs000007.v26.pht000009.v2
# 24      FHS1var25  phs000007.v26.pht000009.v2
# 25      FHS1var26  phs000007.v26.pht000009.v2
# 26      FHS1var27  phs000007.v26.pht000009.v2
# 27      FHS1var28  phs000007.v26.pht000009.v2
# 28      FHS1var29  phs000007.v26.pht000009.v2
# 29      FHS1var30  phs000007.v26.pht000009.v2
# ...           ...                         ...
# 133527    4151748                         NaN
# 133528    4135206                         NaN
# 133529    4136067                         NaN
# 133530    4135210                         NaN
# 133531    4136354                         NaN
# 133532    4136068                         NaN
# 133533   46273656                         NaN
# 133534     444028                         NaN
# 133535    4135724                         NaN
# 133536   42535498                         NaN
# 133537     762286                         NaN
# 133538   37399733                         NaN
# 133539    4135212                         NaN
# 133540     435230                         NaN
# 133541    4135725                         NaN
# 133542    4136071                         NaN
# 133543    4135213                         NaN
# 133544    4135726                         NaN
# 133545    4136072                         NaN
# 133546    4135226                         NaN
# 133547    4135727                         NaN
# 133548    4136073                         NaN
# 133549    4135728                         NaN
# 133550    4202698                         NaN
# 133551   37003713                         NaN
# 133552    4136075                         NaN
# 133553    4136076                         NaN
# 133554    4136355                         NaN
# 133555    4136077                         NaN
# 133556    4201174                         NaN
#
# [133557 rows x 13 columns]

# %%
# For testing reduce data size
data_orig = data

# %%
data = data_orig

# %%
ref_id_col = 'var_doc_id'
doc_col = 'variable_description'
corpora = corpus.build_corpora([doc_col], [data], ref_id_col)
len(corpora[0]), len(corpora[0][0])
# Out:
# (133557, 2)

# %%
tfidf_matrix = corpus.calc_tfidf(corpora)
tfidf_matrix.shape
# Out:
# (133557, 42253)

# %%
#reload(vocab_similarity)

# %%
v = vocab_similarity.VariableSimilarityCalculator(data[ref_id_col])
v.init_cache()
scores = v.score_variables(corpora[0], tfidf_matrix)
# Out:
# Finding valid ref ids
# Multiplying matrices
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-15-a66b952aca66> in <module>()
#       1 v = vocab_similarity.VariableSimilarityCalculator(data[ref_id_col])
#       2 v.init_cache()
# ----> 3 scores = v.score_variables(corpora[0], tfidf_matrix)
#
# /home/harrison/Dropbox/Documents/Laura/automatic-variable-mapping/automatic_variable_mapping/vocab_similarity.pyc in score_variables(self, corpora, tfidf, num_cpus)
#     143             print "Multiplying matrices"
#     144             cosine_similarities = np.matmul(tfidf.toarray(),
# --> 145                                             sub_tfidf.toarray().transpose())
#     146
#     147             cache = list()
#
# MemoryError:

# %%
scores
# Out:
#          reference var   paired var     score
# 0             FHS1var1    FHS1var75  0.805718
# 1             FHS1var1   FHS1var193  0.800470
# 2             FHS1var1   FHS1var337  0.787576
# 3             FHS1var1   FHS1var155  0.785568
# 4             FHS1var1    FHS1var63  0.785528
# 5             FHS1var1   FHS1var456  0.784782
# 6             FHS1var1   FHS1var372  0.774645
# 7             FHS1var1     FHS4var1  0.604210
# 8             FHS1var1     FHS3var3  0.604210
# 9             FHS1var1     FHS5var1  0.604210
# 10            FHS1var1     FHS6var1  0.604210
# 11            FHS1var1    FHS22var2  0.598027
# 12            FHS1var1    FHS13var1  0.558658
# 13            FHS1var1   FHS1var154  0.538583
# 14            FHS1var1   FHS1var201  0.532949
# 15            FHS1var1   FHS1var268  0.519385
# 16            FHS1var1   FHS1var168  0.517307
# 17            FHS1var1   FHS1var437  0.516496
# 18            FHS1var1   FHS1var351  0.506161
# 19            FHS1var1    FHS2var24  0.500472
# 20            FHS1var1     FHS6var2  0.486512
# 21            FHS1var1     FHS4var2  0.486512
# 22            FHS1var1     FHS5var2  0.486512
# 23            FHS1var1   FHS13var48  0.451274
# 24            FHS1var1   FHS27var15  0.451274
# 25            FHS1var1   FHS19var27  0.451274
# 26            FHS1var1   FHS14var50  0.451274
# 27            FHS1var1    FHS26var9  0.444708
# 28            FHS1var1   FHS15var45  0.444708
# 29            FHS1var1  FHS16var393  0.400501
# ...                ...          ...       ...
# 99989970   FHS28var387   FHS21var77  0.000000
# 99989971   FHS28var387   FHS21var76  0.000000
# 99989972   FHS28var387   FHS21var75  0.000000
# 99989973   FHS28var387   FHS21var74  0.000000
# 99989974   FHS28var387   FHS21var73  0.000000
# 99989975   FHS28var387   FHS21var72  0.000000
# 99989976   FHS28var387   FHS21var71  0.000000
# 99989977   FHS28var387   FHS21var70  0.000000
# 99989978   FHS28var387   FHS21var69  0.000000
# 99989979   FHS28var387   FHS21var68  0.000000
# 99989980   FHS28var387   FHS21var83  0.000000
# 99989981   FHS28var387   FHS21var85  0.000000
# 99989982   FHS28var387  FHS21var102  0.000000
# 99989983   FHS28var387   FHS21var86  0.000000
# 99989984   FHS28var387  FHS21var101  0.000000
# 99989985   FHS28var387  FHS21var100  0.000000
# 99989986   FHS28var387   FHS21var99  0.000000
# 99989987   FHS28var387   FHS21var98  0.000000
# 99989988   FHS28var387   FHS21var97  0.000000
# 99989989   FHS28var387   FHS21var96  0.000000
# 99989990   FHS28var387   FHS21var95  0.000000
# 99989991   FHS28var387   FHS21var94  0.000000
# 99989992   FHS28var387   FHS21var93  0.000000
# 99989993   FHS28var387   FHS21var92  0.000000
# 99989994   FHS28var387   FHS21var91  0.000000
# 99989995   FHS28var387   FHS21var90  0.000000
# 99989996   FHS28var387   FHS21var89  0.000000
# 99989997   FHS28var387   FHS21var88  0.000000
# 99989998   FHS28var387   FHS21var87  0.000000
# 99989999   FHS28var387     FHS1var1  0.000000
#
# [99990000 rows x 3 columns]

# %%
scores.to_csv("output/combined_dbGaP_SNOMED_sim_scores.csv")
